# %%
# %pip install -qU langchain langchain-google-genai langchain_community tavily-python aiosqlite langchain-tavily
# %pip install -qU langgraph-checkpoint-sqlite
# %pip install -qU langgraph langgraph-checkpoint-sqlite
# %pip install -qU langgraph
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, AIMessage, ChatMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver
conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()

GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
from typing import TypedDict, List

class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model='gemini-3.1-flash-lite', temperature=0)

# %%
PLAN_PROMPT = """Eres un escritor especialista con la tarea de crear un esquema de alto nivel para una redacción. \
Escribe este esquema para el tema proporcionado por el usuario. Presenta un plan de la redacción junto con cualesquiera notas \
o instrucciones relevantes para las secciones."""

# %%
WRITER_PROMPT = """Eres un asistente de redacción con la tarea de escribir excelentes redacciones de 5 párrafos. \
Genera la mejor redacción posible para la solicitud del usuario y el esquema inicial. \
Si el usuario proporciona críticas, responde con una versión revisada de tus intentos anteriores. \
Utiliza toda la información a continuación según sea necesario:

------------

{content}"""

# %%
REFLECTION_PROMPT = """Eres un profesor corrigiendo una redacción presentada. \
Genera una crítica y recomendaciones para la entrega del usuario. \
Proporciona recomendaciones detalladas, incluyendo solicitudes sobre extensión, profundidad, estilo, etc."""

# %%
RESEARCH_PLAN_PROMPT = """Eres un investigador encargado de proporcionar información que puede \
ser utilizada al escribir la siguiente redacción. Genera una lista de consultas de investigación que \
recopilen cualquier información relevante. Genera como máximo 3 consultas."""

# %%
RESEARCH_CRITIQUE_PROMPT = """Eres un investigador encargado de proporcionar información que puede \
ser utilizada al realizar cualquier revisión solicitada (según se describe a continuación). \
Genera una lista de consultas de investigación que recopilen cualquier información relevante. Genera \
como máximo 3 consultas."""

# %%
from pydantic import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
import os
from tavily import TavilyClient
tavily = TavilyClient(api_key=TAVILY_API_KEY)

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}"
    )
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
    ]
    response = model.invoke(messages)
    return {
        "draft": response.content,
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT),
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate",
    should_continue,
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")
builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display, Markdown
import os

print("\n--- Tratando de Generar el PNG del Grafo vía Mermaid (Requiere Playwright!) ---")
try:
    image_data = graph.get_graph().draw_mermaid_png()
    display(Image(data=image_data))
    print("¡Grafo PNG generado y exhibido con éxito!")

except Exception as e:
    print(f"\nError al tratar de generar el PNG del grafo: {e}")
    print("Esto posiblemente se debe a que:")
    print("1. El método `.draw_mermaid_png()` no existe en su versión de LangGraph.")
    print("2. Faltan dependencias como 'playwright' o sus drivers no fueron instalados.")
    print("   Trata con: pip install playwright && playwright install")
    print("3. Otro error inesperado al acceder al grafo o renderizar.")

    print("\n--- Tratando generar únicamente el código Mermaid (Fallback) ---")
    try:
        mermaid_code = graph.get_graph().draw_mermaid()
        print("\n--- Código Mermaid Generado (Pégalo en https://mermaid.live/ o utiliza Markdown en un entorno compatible) ---")
        print(mermaid_code)
    
    except Exception as e_mermaid:
        print(f"Error al generar el código Mermaid: {e_mermaid}")
        print("Verifica si `graph.get_graph()` está correcto y es accesible.")
# Out:
# --- Tratando de Generar el PNG del Grafo vía Mermaid (Requiere Playwright!) ---
# ¡Grafo PNG generado y exhibido con éxito!

# %%
thread = {"configurable": {"thread_id": "5"}}
for s in graph.stream({
    "task": "Cuál es la diferencia entre LangChain y LangSmith",
    "max_revisions": 2,
    "revision_number": 1,
    "content": [],
}, thread):
    print(s)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'planner': {'plan': [{'type': 'text', 'text': 'Este esquema está diseñado para estructurar una redacción técnica clara que permita diferenciar dos herramientas fundamentales del ecosistema de desarrollo con LLMs (Large Language Models).\n\n---\n\n# Esquema de Redacción: LangChain vs. LangSmith\n\n## I. Introducción\n*   **Contexto:** El auge de las aplicaciones basadas en LLMs y la necesidad de herramientas de orquestación y observabilidad.\n*   **Definición breve:**\n    *   **LangChain:** El "framework" de construcción (el motor).\n    *   **LangSmith:** La plataforma de depuración y evaluación (el taller de mantenimiento).\n*   **Tesis:** Mientras que LangChain proporciona la infraestructura para crear aplicaciones complejas, LangSmith ofrece la visibilidad necesaria para asegurar que dichas aplicaciones funcionen de manera fiable y eficiente.\n\n## II. LangChain: El Framework de Orquestación\n*   **Propósito:** Facilitar la creación de aplicaciones mediante la composición de componentes.\n*   **Componentes clave:**\n    *   *Model I/O:* Interfaz con diferentes proveedores de modelos.\n    *   *Retrieval:* Gestión de datos externos (RAG - Retrieval Augmented Generation).\n    *   *Chains:* Secuenciación de llamadas lógicas.\n    *   *Agents:* Uso de LLMs para tomar decisiones y ejecutar acciones.\n*   **Nota para el redactor:** Enfatizar que LangChain es una **biblioteca de código** que se instala en el entorno de desarrollo.\n\n## III. LangSmith: La Plataforma de Observabilidad y Evaluación\n*   **Propósito:** Monitorizar, depurar y optimizar el rendimiento de las aplicaciones creadas con LangChain (o cualquier otro framework).\n*   **Funcionalidades clave:**\n    *   *Tracing:* Visualización paso a paso de la ejecución de las cadenas.\n    *   *Testing/Evaluation:* Comparación de resultados frente a datasets de prueba.\n    *   *Prompt Playground:* Experimentación rápida con diferentes prompts y modelos.\n*   **Nota para el redactor:** Destacar que LangSmith es un **servicio SaaS** (plataforma) que se conecta a la aplicación para analizar su comportamiento en tiempo real.\n\n## IV. Tabla Comparativa (Diferencias Clave)\n| Característica | LangChain | LangSmith |\n| :--- | :--- | :--- |\n| **Naturaleza** | Framework de desarrollo | Plataforma de observabilidad |\n| **Función principal** | Construir y conectar componentes | Analizar y mejorar el rendimiento |\n| **Uso** | Durante la escritura del código | Durante el testing y producción |\n| **Dependencia** | Es el núcleo de la app | Es un complemento opcional (pero recomendado) |\n\n## V. La Sinergia: ¿Por qué usar ambos?\n*   **El ciclo de vida del desarrollo:** Cómo LangChain permite prototipar rápido y LangSmith permite escalar a producción con confianza.\n*   **El problema de la "caja negra":** Explicar cómo LangSmith resuelve la dificultad de entender por qué un LLM falló dentro de una cadena compleja de LangChain.\n\n## VI. Conclusión\n*   **Resumen:** LangChain es la herramienta de creación; LangSmith es la herramienta de control de calidad.\n*   **Reflexión final:** Para proyectos profesionales, no se trata de elegir uno sobre otro, sino de integrar ambos para crear aplicaciones de IA robustas y mantenibles.\n\n---\n\n### Notas e instrucciones para el redactor:\n\n1.  **Tono:** Profesional, técnico pero accesible. Evita el exceso de jerga sin explicarla brevemente.\n2.  **Enfoque:** Asegúrate de que el lector entienda que **no son competidores**, sino herramientas complementarias. Es un error común pensar que se debe elegir uno u otro.\n3.  **Analogía sugerida:** Puedes usar la analogía de un coche: LangChain es el motor y el chasis (lo que hace que el coche se mueva), mientras que LangSmith es el panel de control y el equipo de diagnóstico en el taller (lo que te dice por qué el coche no está rindiendo como debería).\n4.  **Actualidad:** Menciona brevemente que, aunque LangSmith funciona mejor con LangChain, es agnóstico y puede integrarse con otros frameworks, l ...
# {'research_plan': {'content': ["\u200dLangChain is a framework for chaining LLM calls and connecting to tools and data sources. LangGraph is the orchestration layer for agents that need to loop, branch, and hold state. LangSmith is the platform for tracing, evaluating, and optionally hosting agents built with either of the other two.\n\nDo I need all three to build an agent? [...] •\n\nLangSmith provides observability. It helps developers debug, trace, evaluate, and monitor LLM applications and AI agents running in production.\n\n•\n\nThey're designed to work together. LangGraph is built on top of LangChain, while LangSmith integrates with both to provide end-to-end visibility into your AI applications.\n\n• [...] •\n\nLangChain builds LLM applications. It provides components for prompts, models, retrieval, tools, memory, and workflows, making it ideal for chatbots, RAG applications, and AI assistants.\n\n•\n\nLangGraph orchestrates AI agents. It extends LangChain with stateful execution, memory, checkpointing, branching logic, and human-in-the-loop workflows for complex agent systems.\n\n•", "every decision point, every tool invocation. That's the architecture. LangChain is the vocabulary. LangGraph is the control flow. LangSmith is the visibility layer. Each one solves a distinct problem. Together, they cover the full surface area of building AI systems that actually work in production. Now, none of this means LangChain is perfect. The most common criticism you'll hear from engineers, the abstractions can be too heavy. When something breaks, you're often debugging through multiple", 'Si trabaja con modelos de lenguaje de gran tamaño (LLM), es probable que se haya encontrado con LangChain, un marco de código abierto ampliamente utilizado diseñado para simplificar el desarrollo de aplicaciones basadas en LLM. LangChain agiliza la creación de aplicaciones de inteligencia artificial (IA) al proporcionar componentes básicos listos para usar que los desarrolladores pueden utilizar para conectar los LLM con fuentes de datos del mundo real. En lugar de realizar la codificación [...] Una de las principales ventajas de LangChain es su enfoque estructurado. En lugar de escribir integraciones personalizadas desde cero, los desarrolladores pueden usar plantillas y módulos prediseñados para conectar LLM con diferentes herramientas. Este marco prediseñado es beneficioso para los desarrolladores que desean crear aplicaciones rápidamente sin sumergirse en las complejidades de la orquestación, el ajuste fino o la recuperación de datos de bajo nivel de LLM. [...] ¿Por qué no LangChain?\n\nLangChain está construido sobre estructuras de encadenamiento predefinidas, que pueden resultar rígidas para los desarrolladores que necesitan aplicaciones LLM personalizables con automatización de flujo de trabajo ajustada. LlamaIndex es útil para aplicaciones con gran cantidad de datos, mientras que Flowise AI es ideal para desarrolladores que prefieren un enfoque visual y no-code.\n\n### Recuperación de datos, fuentes de conocimiento y búsqueda vectorial', 'LangChain simplifica el desarrollo de la IA con modelos de lenguaje grandes (LLM) al ofrecer componentes modulares y plantillas prediseñadas para crear aplicaciones como chatbots y resumidores. Se integra perfectamente con los LLM, como el GPT-3.5 y los modelos de chat, lo que permite realizar tareas como completar textos y generar conversaciones. LangChain opera a través de cadenas de acciones, lo que garantiza una implementación eficiente de manera estructurada. [...] Langchain es un marco de código abierto que facilita el desarrollo de aplicaciones impulsadas por modelos de lenguaje grande (LLM), el pináculo actual de la evolución del procesamiento del lenguaje natural (PNL).', 'Plataforma integral: LangSmith consolida todas las funciones principales—depuración, pruebas, despliegue, monitoreo—en una plataforma cohesiva. La supervisión del despliegue en el mundo real con LangSmith ayuda a los equipos  ...
# {'generate': {'draft': [{'type': 'text', 'text': 'El auge de las aplicaciones basadas en modelos de lenguaje (LLMs) ha transformado la forma en que construimos software, dando lugar a un ecosistema de herramientas especializadas. En este contexto, es común confundir las funciones de LangChain y LangSmith, dos pilares fundamentales desarrollados por la misma organización. Mientras que LangChain actúa como el motor de construcción que permite ensamblar aplicaciones complejas, LangSmith funciona como el taller de diagnóstico y control de calidad. La tesis central es que, lejos de ser competidores, ambos se complementan: LangChain proporciona la infraestructura necesaria para crear, mientras que LangSmith ofrece la visibilidad indispensable para asegurar que dichas aplicaciones operen con fiabilidad y eficiencia en entornos de producción.\n\nLangChain es, en esencia, un framework de desarrollo diseñado para facilitar la orquestación de componentes de IA. Su propósito principal es simplificar la creación de aplicaciones mediante la composición modular de elementos como interfaces de modelos (Model I/O), sistemas de recuperación de datos (RAG) y agentes autónomos. Al ser una biblioteca de código que se integra directamente en el entorno de desarrollo, LangChain permite a los ingenieros secuenciar llamadas lógicas y gestionar la memoria de las conversaciones sin tener que programar cada integración desde cero. Es la herramienta que permite que una aplicación "piense" y ejecute acciones, convirtiendo conceptos abstractos en flujos de trabajo ejecutables.\n\nPor otro lado, LangSmith es una plataforma de observabilidad y evaluación diseñada para monitorizar el comportamiento de las aplicaciones de IA. A diferencia de LangChain, que reside en el código, LangSmith es un servicio SaaS que se conecta a la aplicación para proporcionar una ventana transparente a lo que ocurre dentro de la "caja negra" de los LLMs. Sus funcionalidades clave incluyen el *tracing* detallado, que permite visualizar paso a paso cada invocación de herramientas o decisión del modelo, y herramientas de evaluación que comparan los resultados frente a datasets de prueba. Es el entorno donde los desarrolladores depuran errores, experimentan con nuevos prompts y optimizan el rendimiento del sistema en tiempo real.\n\nLa distinción entre ambos es clara cuando analizamos su naturaleza y momento de uso. LangChain es el framework de construcción que se utiliza durante la fase de escritura del código para definir la arquitectura de la aplicación. En contraste, LangSmith es la plataforma de análisis que se utiliza durante el testing y la puesta en producción para garantizar la calidad. Aunque LangSmith está optimizado para trabajar con LangChain, es importante destacar que es agnóstico y puede integrarse con otros frameworks, lo que subraya su valor como capa de visibilidad independiente. Mientras que LangChain es el chasis y el motor que hace que el vehículo se mueva, LangSmith es el panel de control y el equipo de diagnóstico que nos indica por qué el vehículo no está rindiendo como debería.\n\nEn conclusión, la relación entre LangChain y LangSmith es de sinergia absoluta. Para cualquier proyecto profesional que aspire a la escalabilidad, no se trata de elegir una herramienta sobre la otra, sino de integrar ambas para cubrir el ciclo de vida completo del desarrollo de IA. LangChain permite prototipar con rapidez y flexibilidad, mientras que LangSmith aporta la confianza necesaria para desplegar soluciones robustas y mantenibles. Al combinar la capacidad de construcción del primero con la capacidad de supervisión del segundo, los desarrolladores pueden transformar ideas experimentales en aplicaciones de IA que realmente funcionan en el mundo real.', 'extras': {'signature': 'EnEKbwERTTIPRmM5zrDr676VZ482VpdpPtB01vHuZiqo3T/qKhZjV13ed8ikJqVt5ofQ8mXIyUPpzVoshvvhnj2yO3i2MVe/wAwV+TXp2MJoGtiwsreh3CHBWf5q0yPWCOLYBLqpL/6Kx15Y/3eDQNw6Vw=='}}], 'revision_number': 2}}
# {'reflect': {'critique': [{'type': 'text', 'text': 'Hola. He revisado tu redacción sobre la relación entre LangChain y LangSmith. A continuación, presento mi evaluación como profesor, estructurada en puntos fuertes, áreas de mejora y recomendaciones específicas.\n\n---\n\n### **Evaluación General**\nTu texto es **excelente en términos de claridad, estructura y precisión técnica**. Has logrado explicar conceptos complejos de manera accesible sin perder el rigor necesario. La analogía del "chasis/motor" frente al "panel de control" es muy efectiva y ayuda al lector a visualizar la diferencia funcional de inmediato.\n\n### **Puntos Fuertes**\n1.  **Estructura lógica:** El texto sigue un orden impecable: introducción (tesis), desarrollo (definición de cada herramienta), comparativa (diferenciación) y conclusión (síntesis).\n2.  **Precisión terminológica:** El uso de términos como *orquestación*, *tracing*, *RAG* y *agnóstico* es correcto y está bien contextualizado.\n3.  **Estilo:** El tono es profesional, académico y directo. No hay redundancias innecesarias.\n\n---\n\n### **Recomendaciones de Mejora**\n\n#### **1. Profundidad Técnica (El "Cómo")**\nAunque explicas *qué* hacen, el texto se mantiene en un nivel conceptual. Para elevar el nivel de la redacción, te sugiero añadir un breve párrafo sobre **la integración técnica**.\n*   *Sugerencia:* Menciona brevemente cómo se conectan (por ejemplo, mediante variables de entorno o el uso de decoradores/callbacks). Esto daría al lector una idea de que la integración no es solo conceptual, sino operativa.\n\n#### **2. Extensión y Alcance**\nEl texto es conciso, lo cual es bueno, pero si el objetivo es un artículo técnico o un ensayo, podrías expandir la sección de **"Casos de uso"**.\n*   *Sugerencia:* Añade un ejemplo concreto. Por ejemplo: *"Imaginemos un chatbot de atención al cliente: LangChain gestiona la cadena de recuperación de documentos (RAG), mientras que LangSmith permite identificar en qué paso de esa cadena el modelo alucinó o falló al recuperar la información"*. Esto aterrizaría la teoría en la práctica.\n\n#### **3. Matices sobre el Ecosistema**\nMencionas que LangSmith es agnóstico, lo cual es un punto muy importante. Podrías enfatizar un poco más **por qué** un desarrollador que *no* usa LangChain debería considerar LangSmith. Esto refuerza tu tesis de que son herramientas complementarias pero independientes.\n\n#### **4. Estilo y Fluidez**\n*   **Variedad léxica:** En el tercer párrafo, utilizas "es una plataforma..." y "es un servicio...". Intenta variar los verbos de enlace para evitar la repetición de la estructura sujeto-verbo-predicado.\n*   **Conectores:** El uso de conectores es bueno, pero podrías añadir alguno más sofisticado para unir los párrafos de desarrollo, como: *"Más allá de la arquitectura de construcción, es imperativo considerar la dimensión operativa..."*.\n\n---\n\n### **Resumen de Tareas para la próxima entrega:**\n\n1.  **Añadir un ejemplo práctico:** Incluye un escenario de uso real (como el ejemplo del chatbot mencionado arriba) para ilustrar la sinergia entre ambas herramientas.\n2.  **Expandir la sección de integración:** Explica brevemente que la implementación de LangSmith suele requerir cambios mínimos en el código de LangChain (ej. configuración de claves API), lo que reduce la fricción de adopción.\n3.  **Revisión de estilo:** Realiza una lectura en voz alta para detectar repeticiones de palabras (especialmente el uso de "es" o "permite").\n4.  **Extensión sugerida:** Si el texto actual tiene unas 450 palabras, intenta llevarlo a unas 600-650 añadiendo el ejemplo práctico y una breve reflexión sobre el futuro de la observabilidad en IA.\n\n**Calificación preliminar:** 9/10.\nEl texto es sólido, profesional y está muy bien redactado. Con los ajustes de profundidad técnica y el ejemplo práctico, será un artículo de referencia excelente para cualquier blog técnico o publicación académica.\n\n¿Deseas que redacte un ejemplo de cómo integra ...
# {'research_critique': {'content': ["\u200dLangChain is a framework for chaining LLM calls and connecting to tools and data sources. LangGraph is the orchestration layer for agents that need to loop, branch, and hold state. LangSmith is the platform for tracing, evaluating, and optionally hosting agents built with either of the other two.\n\nDo I need all three to build an agent? [...] •\n\nLangSmith provides observability. It helps developers debug, trace, evaluate, and monitor LLM applications and AI agents running in production.\n\n•\n\nThey're designed to work together. LangGraph is built on top of LangChain, while LangSmith integrates with both to provide end-to-end visibility into your AI applications.\n\n• [...] •\n\nLangChain builds LLM applications. It provides components for prompts, models, retrieval, tools, memory, and workflows, making it ideal for chatbots, RAG applications, and AI assistants.\n\n•\n\nLangGraph orchestrates AI agents. It extends LangChain with stateful execution, memory, checkpointing, branching logic, and human-in-the-loop workflows for complex agent systems.\n\n•", "every decision point, every tool invocation. That's the architecture. LangChain is the vocabulary. LangGraph is the control flow. LangSmith is the visibility layer. Each one solves a distinct problem. Together, they cover the full surface area of building AI systems that actually work in production. Now, none of this means LangChain is perfect. The most common criticism you'll hear from engineers, the abstractions can be too heavy. When something breaks, you're often debugging through multiple", 'Si trabaja con modelos de lenguaje de gran tamaño (LLM), es probable que se haya encontrado con LangChain, un marco de código abierto ampliamente utilizado diseñado para simplificar el desarrollo de aplicaciones basadas en LLM. LangChain agiliza la creación de aplicaciones de inteligencia artificial (IA) al proporcionar componentes básicos listos para usar que los desarrolladores pueden utilizar para conectar los LLM con fuentes de datos del mundo real. En lugar de realizar la codificación [...] Una de las principales ventajas de LangChain es su enfoque estructurado. En lugar de escribir integraciones personalizadas desde cero, los desarrolladores pueden usar plantillas y módulos prediseñados para conectar LLM con diferentes herramientas. Este marco prediseñado es beneficioso para los desarrolladores que desean crear aplicaciones rápidamente sin sumergirse en las complejidades de la orquestación, el ajuste fino o la recuperación de datos de bajo nivel de LLM. [...] ¿Por qué no LangChain?\n\nLangChain está construido sobre estructuras de encadenamiento predefinidas, que pueden resultar rígidas para los desarrolladores que necesitan aplicaciones LLM personalizables con automatización de flujo de trabajo ajustada. LlamaIndex es útil para aplicaciones con gran cantidad de datos, mientras que Flowise AI es ideal para desarrolladores que prefieren un enfoque visual y no-code.\n\n### Recuperación de datos, fuentes de conocimiento y búsqueda vectorial', 'LangChain simplifica el desarrollo de la IA con modelos de lenguaje grandes (LLM) al ofrecer componentes modulares y plantillas prediseñadas para crear aplicaciones como chatbots y resumidores. Se integra perfectamente con los LLM, como el GPT-3.5 y los modelos de chat, lo que permite realizar tareas como completar textos y generar conversaciones. LangChain opera a través de cadenas de acciones, lo que garantiza una implementación eficiente de manera estructurada. [...] Langchain es un marco de código abierto que facilita el desarrollo de aplicaciones impulsadas por modelos de lenguaje grande (LLM), el pináculo actual de la evolución del procesamiento del lenguaje natural (PNL).', 'Plataforma integral: LangSmith consolida todas las funciones principales—depuración, pruebas, despliegue, monitoreo—en una plataforma cohesiva. La supervisión del despliegue en el mundo real con LangSmith ayuda a los equi ...
# {'generate': {'draft': [{'type': 'text', 'text': 'El auge de las aplicaciones basadas en modelos de lenguaje (LLMs) ha transformado el panorama del desarrollo de software, exigiendo herramientas especializadas para gestionar su complejidad. En este ecosistema, dos nombres destacan por su relevancia: LangChain y LangSmith. Mientras que LangChain actúa como el motor fundamental para la construcción de aplicaciones, LangSmith funciona como el taller de diagnóstico y mantenimiento. La tesis central es que, aunque cumplen roles distintos, ambos son piezas complementarias: LangChain proporciona la infraestructura necesaria para crear aplicaciones complejas, mientras que LangSmith ofrece la visibilidad crítica para asegurar que dichas aplicaciones operen de manera fiable y eficiente en entornos de producción.\n\nLangChain es, en esencia, un framework de orquestación diseñado para facilitar la creación de aplicaciones mediante la composición de componentes modulares. Como biblioteca de código que se integra directamente en el entorno de desarrollo, permite a los ingenieros conectar LLMs con fuentes de datos externas y herramientas mediante el uso de "cadenas" (chains) y agentes. Sus capacidades incluyen la gestión de la memoria, la recuperación de información (RAG) y la interfaz con diversos proveedores de modelos. En términos automotrices, LangChain es el motor y el chasis; es la estructura que permite que la aplicación "se mueva" y ejecute tareas lógicas complejas de manera estructurada.\n\nPor otro lado, LangSmith es una plataforma de observabilidad y evaluación diseñada para monitorizar, depurar y optimizar el rendimiento de las aplicaciones. A diferencia de LangChain, que se utiliza durante la escritura del código, LangSmith es un servicio SaaS que se conecta a la aplicación para analizar su comportamiento en tiempo real. Sus funcionalidades clave, como el *tracing* (rastreo paso a paso de las ejecuciones), el *testing* automatizado y el *Prompt Playground*, permiten a los desarrolladores abrir la "caja negra" de los LLMs. Si LangChain es el motor, LangSmith es el panel de control y el equipo de diagnóstico que permite identificar por qué un sistema no está rindiendo como debería.\n\nLa distinción entre ambas herramientas es clara cuando se analizan sus funciones principales. Mientras que LangChain se enfoca en la construcción y conexión de componentes, LangSmith se especializa en el análisis y la mejora del rendimiento. Es importante destacar que, aunque LangSmith está optimizado para trabajar en conjunto con LangChain, es una plataforma agnóstica que puede integrarse con otros frameworks. Esta flexibilidad añade un valor significativo, ya que permite a los equipos mantener una visibilidad constante sobre sus flujos de trabajo, independientemente de la arquitectura subyacente, facilitando la transición desde el prototipado rápido hasta el despliegue a escala.\n\nEn conclusión, la relación entre LangChain y LangSmith no es de competencia, sino de sinergia. Para cualquier proyecto profesional que busque robustez y mantenibilidad, no se trata de elegir una herramienta sobre la otra, sino de integrar ambas para cubrir el ciclo de vida completo del desarrollo de IA. LangChain proporciona la capacidad de creación, mientras que LangSmith garantiza el control de calidad necesario para que las aplicaciones de inteligencia artificial sean confiables. Al combinar la potencia de orquestación de uno con la capacidad de diagnóstico del otro, los desarrolladores pueden construir sistemas de IA que no solo funcionen, sino que evolucionen con éxito en entornos reales.', 'extras': {'signature': 'EnEKbwERTTIPNA+r0hBUsflYWHqfm39k6vgMoPtkFfuzhGwl2qfTo56/83yaNzQtQDpv0OHFB7ClTwDwc+ZNymDh1uQpi6CrKMZnLBhFr/r10Q29yPcNv5oFwh3Zaps/+kL2YNd4zhe4MimRuK/tGmIi7A=='}}], 'revision_number': 3}}
